# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
ls ../output/databento
# Out:
# glbx-mdp3-20240806.csv

# %%
# !head ../output/databento/glbx-mdp3-20240806.csv
# Out:
# instrument,timestamp,action,side,size,price,ts_delta,bq,bp,aq,ap,is_last
# ESH5-ESM5,1722902400.0,R,N,0,9223372036854775807,0,nan,nan,nan,nan,False
# ESH5-ESM5,1722902400.0,A,B,2,-50000000000,0,2,-50.0,nan,nan,False
# ESH5-ESM5,1722902400.0,A,A,2,65950000000,0,2,-50.0,2,65.95,False
# ESH5-ESM5,1722902400.0,A,A,1,100000000000,0,2,-50.0,2,65.95,False
# ESH5-ESM5,1722902400.0,A,B,1,-55000000000,0,2,-50.0,2,65.95,False
# ESH5-ESM5,1722902400.0,A,A,2,70000000000,0,2,-50.0,2,65.95,True
# ESH5-ESM5,1722902400.0,R,N,0,9223372036854775807,0,nan,nan,nan,nan,False
# ESH5-ESM5,1722902400.0,A,A,1,228500000000,0,nan,nan,1,228.5,False
# ESH5-ESM5,1722902400.0,A,A,1,230800000000,0,nan,nan,1,228.5,False

# %%
df = pd.read_csv('../output/databento/glbx-mdp3-20240806.csv',nrows=100000)
df = df.set_index(df.timestamp)

# %%
(1/df[df.action=='T'].timestamp.diff()).rolling(50).mean().plot()
# Out:
# <Axes: xlabel='timestamp'>

# %%
df.timestamp.diff().plot()
# Out:
# <Axes: xlabel='timestamp'>

# %%
df['bp'] = df.bp.astype(float)

# %%
df[df.bp == df.bp.min()]
# Out:
#              instrument     timestamp action side  size  ts_delta  bq     bp  \
# timestamp
# 1.725459e+09  ESH5-ESM5  1.725459e+09      T    A     1     13511  51  50.75
# 1.725481e+09  ESH5-ESM5  1.725481e+09      T    A     1     14762   1  50.75
#
#               aq     ap  is_last
# timestamp
# 1.725459e+09   2  51.85    False
# 1.725481e+09   2  51.10    False

# %%
(1/df.head(80000).timestamp.diff()).ewm(span=10000).mean().tail(70000).plot()
# Out:
# <Axes: xlabel='timestamp'>

# %%
df[df.instrument=='ESH5-ESM5'][['bp','ap']].head(100).plot()
# Out:
# <Axes: xlabel='timestamp'>

# %%
df.timestamp.max()-df.timestamp.min()
# Out:
# np.float64(86399.9288315773)
